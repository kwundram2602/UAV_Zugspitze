# %% [markdown]
# # UAV

# %%
import os
import whitebox_workflows as wbw
from whitebox_workflows import download_sample_data, show, WbEnvironment
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import rioxarray as riox

print(os.getcwd())
wbe = WbEnvironment()
# Out:
# d:\EAGLE\Zugspitze\UAV_Zugspitze

# %%
dates = os.listdir("./uas_data/")
print(dates)
folders = [os.path.join(os.getcwd(),"uas_data",date) for date in dates]
print(folders)
# Out:
# ['2024-09-19', '2024-10-25', '2025-02-25', '2025-04-02', '2025-04-23', '2025-06-04', '2025-08-20', '2026-01-17']
# ['d:\\EAGLE\\Zugspitze\\UAV_Zugspitze\\uas_data\\2024-09-19', 'd:\\EAGLE\\Zugspitze\\UAV_Zugspitze\\uas_data\\2024-10-25', 'd:\\EAGLE\\Zugspitze\\UAV_Zugspitze\\uas_data\\2025-02-25', 'd:\\EAGLE\\Zugspitze\\UAV_Zugspitze\\uas_data\\2025-04-02', 'd:\\EAGLE\\Zugspitze\\UAV_Zugspitze\\uas_data\\2025-04-23', 'd:\\EAGLE\\Zugspitze\\UAV_Zugspitze\\uas_data\\2025-06-04', 'd:\\EAGLE\\Zugspitze\\UAV_Zugspitze\\uas_data\\2025-08-20', 'd:\\EAGLE\\Zugspitze\\UAV_Zugspitze\\uas_data\\2026-01-17']

# %%
dsms = {}
rgbs = {}
snow_m = []
for date,folder in zip(dates,folders):
    files = os.listdir(folder)
    dsm_files = [f for f in files if "dsm" in f.lower()]
    dsms[date] = dsm_files
    rgb_files = [f for f in files if "rgb" in f.lower()]
    rgbs[date] = rgb_files
    

print(dsms)
print(rgbs)
# Out:
# {'2024-09-19': ['2024-09-19_dsm_10cm_32632.tif'], '2024-10-25': ['2024-10-25_dsm_10cm_32632.tif'], '2025-02-25': ['2025-02-25_dsm_10cm_32632.tif'], '2025-04-02': ['2025-04-02_dsm_10cm_32632.tif'], '2025-04-23': ['2025-04-23_dsm_10cm_32632.tif'], '2025-06-04': ['2025-06-04_dsm_10cm_32632.tif'], '2025-08-20': ['2025-08-20_dsm_10cm_32632.tif'], '2026-01-17': ['2026-01-17_dsm_10cm_32632.tif']}
# {'2024-09-19': ['2024-09-19_rgb_10cm_32632.tif'], '2024-10-25': ['2024-10-25_rgb_10cm_32632.tif'], '2025-02-25': ['2025-02-25_rgb_10cm_32632.tif'], '2025-04-02': ['2025-04-02_rgb_10cm_32632.tif'], '2025-04-23': ['2025-04-23_rgb_10cm_32632.tif'], '2025-06-04': ['2025-06-04_rgb_10cm_32632.tif'], '2025-08-20': ['2025-08-20_rgb_10cm_32632.tif'], '2026-01-17': ['2026-01-17_rgb_10cm_32632.tif']}

# %%
# n_dsms = len(dsms)
# print(n_dsms)
# fig, ax = plt.subplots(int(n_dsms/2), 2, figsize=(12, 4*int(n_dsms/2)))
# ax = ax.flatten()

# for idx, (date, file) in enumerate(dsms.items())
# Out:
# 8
# 2024-09-19_dsm_10cm_32632.tif
# 2024-10-25_dsm_10cm_32632.tif
# 2025-02-25_dsm_10cm_32632.tif
# 2025-04-02_dsm_10cm_32632.tif
# 2025-04-23_dsm_10cm_32632.tif
# 2025-06-04_dsm_10cm_32632.tif
# 2025-08-20_dsm_10cm_32632.tif
# 2026-01-17_dsm_10cm_32632.tif
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File d:\miniconda3\envs\wb_env2\lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File d:\miniconda3\envs\wb_env2\lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# ...
